# %% [markdown]
# <center>
#
# ---
#
# <font color="white" size="6"> <b>automatic1111-sd-colab (beta_ver)</b> </font>
#
# ---
# </center>
#
# ><font color="#33d6ff"><b>README.md</b></font>
#
# <font size="2"><i>Project ini dibuat menggunakan kumpulan repository berbagai macam sumber dari pengguna GitHub, sewaktu-waktu error bisa saja terjadi diluar kendali saya (21sysai).</i></font>
#
# <center>
#
# ---
#
# <p align="left"> <font ><b>Connect with me</b> :</font>
# <a href="https://instagram.com/bagaseka_apr" target="blank"><img align="center" src="https://raw.githubusercontent.com/rahuldkjain/github-profile-readme-generator/master/src/images/icons/Social/instagram.svg" alt="bagaseka_apr" height="30" width="40" /></a>
# <a href="https://fb.com/bagasekaaprs" target="blank"><img align="center" src="https://raw.githubusercontent.com/rahuldkjain/github-profile-readme-generator/master/src/images/icons/Social/facebook.svg" alt="noe999x" height="30" width="40" /></a>
# <a href="https://pinterest.com/21sysai/" target="blank"><img align="center" src="https://upload.wikimedia.org/wikipedia/commons/0/08/Pinterest-logo.png" alt="21sysai" height="30" width="30" /></a>
# <a href="https://pixiv.net/en/users/86925784" target="blank"><img align="center" src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Pixiv_Icon.svg/1200px-Pixiv_Icon.svg.png" alt="21sysai" height="30" width="30" /></a>
# <a href="https://github.com/noe999x" target="blank"><img align="center" src="https://cdn-icons-png.flaticon.com/512/25/25231.png" alt="noe999x" height="30" width="30" /></a></p>
#
# ---
#
# <p align="left"><font><b>Support me</b> :</font></p>
#
# <a href="https://www.buymeacoffee.com/21sysai"> <img align="center" src="https://cdn.buymeacoffee.com/buttons/v2/default-yellow.png" height="50" width="210" alt="21sysai" /></a><a href="https://trakteer.id/21sysai/tip"> <img align="center" src="https://trakteer.id/images/mix/navbar-logo-lite.png" height="50" width="210" alt="21sysai" /></a>
#
# ---
#
# <font color="white" size="3"> <i>@21sysai</i> </font>
#
# ---
# <br><br><br><br>

# %% [markdown]
# ><p align="left"><font size"4" color="white"><b>- Mulai eksekusi instalasi bahan yang diperlukan, harap perhatikan (<i>opsional</i>) bahan.!</font></p>
#
# <font size="3">Tidak semua bahan perlu di install.! Cukup pilih dan install yang diperlukan saja.</font>
# <br><br>
#
# ---
# <font size="4">
# ✔️ STATUS INSTALL HARUS<br>
# ⭕ STATUS INSTALL OPSIONAL</font>
#
# ---

# %%
#@markdown #1. (✔️) SD-WEBUI-A1111

### -warna-font
H = '\033[1;32m'
D = '\033[0m'
M = '\033[1;34m'

### -module
from IPython.display import clear_output, display, HTML
from time import sleep
import base64
import os
import time
from datetime import timedelta
#from google.colab import drive
from IPython.utils import capture
from subprocess import getoutput
from urllib.parse import unquote
from google.colab.output import eval_js
import shutil

### -clone-sd-webui
print(f"{H}Tunggu hingga proses instalasi selesai...{D}")
sleep(8)
# !git clone --depth=1 https://github.com/21sysai/automatic1111-sd-colab/
# %cd /content/automatic1111-sd-colab/
# !git pull
#clear_output()

# %env TF_CPP_MIN_LOG_LEVEL=1

### -ubuntu&python_install
# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt -y install -qq libunwind8-dev aria2 libcairo2-dev pkg-config python3-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb
clear_output()

# !pip install --use-feature=fast-deps -r requirements.txt
# !pip install numpy==1.23.5 --upgrade
# !pip install wget
clear_output()

# %cd /content/automatic1111-sd-colab/models/
# !mkdir -p Stable-diffusion
# %cd /content/automatic1111-sd-colab/models/Stable-diffusion/
# !wget --content-disposition --quiet https://civitai.com/api/download/models/82446/

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print(f"{H}Instalasi selesai...", f"{M}lanjutkan proses berikutnya.{D}")

# %%
#@markdown #2. (✔️) Extensions
print(f"{H}Menginstall extensions...{D}")
sleep(8)

###-encrypt_base64
sysai = base64.b64decode(("d2VidWk=").encode('ascii')).decode('ascii')

# %cd /content/automatic1111-sd-colab/extensions-builtin/
# !git clone https://github.com/GeorgLegato/stable-diffusion-$sysai-artists-ui-tweak sd-artists-ui-tweak
# !git clone https://tinyurl.com/sd-controlnet sd-$sysai-controlnet
# !git clone https://tinyurl.com/infinite-image-browsing infinite-image-browsing
clear_output()

###-extensions_install
# %cd /content/automatic1111-sd-colab/extensions/
# !git clone https://tinyurl.com/sd-huggingface huggingface 
# !git clone https://tinyurl.com/additional-networks additional-networks
# !git clone https://github.com/fkunn1326/openpose-editor openpose-editor
# !git clone https://tinyurl.com/depth-lib depth-lib
# !git clone https://github.com/hnmr293/posex posex
# !git clone https://tinyurl.com/3d-open-pose-editor 3d-open-pose-editor
# !git clone https://tinyurl.com/sd-deforum sd-deforum
# !git clone https://tinyurl.com/sd-two-shot two-shot 
# !git clone https://tinyurl.com/aspect-ratio-helper aspect-ratio-helper
# !git clone https://tinyurl.com/asymmetric-tiling asymmetric-tiling
# !git clone https://tinyurl.com/tagcomplete tagcomplete
# !git clone https://tinyurl.com/sd-SAG sd_SAG
# !git clone https://github.com/Coyote-A/ultimate-upscale-for-automatic1111 ultimate-upscale-for-automatic1111
# !git clone https://github.com/richrobber2/canvas-zoom canvas-zoom
# !git clone https://github.com/Tsukreya/Umi-AI-debloat Umi-AI
# !git clone https://github.com/Bing-su/adetailer adetailer
# !git clone https://github.com/CiaraStrawberry/TemporalKit TemporalKit
# !git clone https://github.com/Extraltodeus/depthmap2mask depthmap2mask
clear_output()

# %cd /content/automatic1111-sd-colab/repositories
# !git clone https://github.com/isl-org/MiDaS MiDaS

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print(f"{H}Instalasi selesai...", f"{M}lanjutkan proses berikutnya.{D}")

# %%
#@markdown #3. (⭕) Controlnet 1.1 & SD1.5 Models
#@markdown  *Install Model ControlNet seperlunya atau Download "All Models (21GB)".*

import os
import urllib.request
print(f"{H}Menginstall models controlnet...{D}")
sleep(8)

clear_output()

Model = "None" #@param ["None", "Canny", "Depth", "Lineart", "MLSD", "Normal", "OpenPose", "Scribble", "Seg", "ip2p", "Shuffle", "Inpaint", "Softedge", "Lineart_Anime", "Tile", "All Models (21GB)"]

model_urls = {
    "Canny": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth',
    "Depth": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth',
    "Lineart": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth',
    "MLSD": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd.pth',
    "Normal": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae.pth',
    "OpenPose": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth',
    "Scribble": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble.pth',
    "Seg": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth',
    "ip2p": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth',
    "Shuffle": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle.pth',
    "Inpaint": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth',
    "Softedge": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth',
    "Lineart_Anime": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime.pth',
    "Tile": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth'
}

output_path = f"/content/automatic1111-sd-colab/extensions-builtin/sd-{sysai}-controlnet/models/"

os.makedirs(output_path, exist_ok=True)  # Create the output directory if it doesn't exist

def download_model(model_url, output_path):
    filename = os.path.basename(model_url)
    output_file = os.path.join(output_path, filename)
    urllib.request.urlretrieve(model_url, output_file)
    return filename

if Model == "All Models (21GB)":
    for model in model_urls:
        model_url = model_urls[model]
        download_model(model_url, output_path)
    print(f"{H}Instalasi selesai...", f"{M}melanjutkan proses berikutnya.{D}")
elif Model != "None":
    model_url = model_urls.get(Model)
    download_model(model_url, output_path)
    print(f"{H}Instalasi selesai...", f"{M}melanjutkan proses berikutnya.{D}")
else:
    clear_output()
    print(f"{H}Instalasi models selesai...", f"{M}lanjutkan proses berikutnya.{D}")

# %%
#@markdown #4. (⭕) VAE Collection & Negtive Embedings [9.3GB]
print(f"{H}Menginstall VAE & embeddings...{D}")
sleep(8)
# %cd /content/automatic1111-sd-colab/models
# !mkdir -p embeddings/negative
# %cd /content/automatic1111-sd-colab/models/embeddings/negative/
# !git clone --quiet https://huggingface.co/embed/negative

# %cd /content/automatic1111-sd-colab/models/
# !mkdir -p VAE
# %cd /content/automatic1111-sd-colab/models/VAE/
# !git clone --quiet https://huggingface.co/Kefasu/sd-vae-collection /content/automatic1111-sd-colab/models/VAE/

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print(f"{H}Instalasi selesai...", f"{M}lanjutkan proses berikutnya.{D}")

# %% [markdown]
# ---
# > <font color="white" size="4"><b>FULL OPSIONAL!</b></font>
#
# Anda bisa langsung skip bagian ini jika tidak memahami cara penggunaannya! Skip ke bagian *INSTALL WEBUI* untuk langsung menginstal bahan terakhir.
#
# ---
#  > <font color="white" size="4"><b>README.md</b></font>
#
# <font size="3">Model tersedia pada website civitai, huggingface, etc.
# Salin link download filenya, bukan salin link user interface web nya.</font>
#
# Contoh penggunaan linknya :
#
# <a role="link" aria-disabled="true"> https://civitai.com/models/43331/majicmix-realistic ❌</a>
#
# <a role="link" aria-disabled="true"> https://civitai.com/api/download/models/82446 ✔️</a></font>
#
# ---

# %%
#@markdown #⭕Optional!
#@markdown #Models & Checkpoint

# %cd /content/automatic1111-sd-colab/models/Stable-diffusion/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

DirectLink_URL_2 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_2

DirectLink_URL_3 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_3

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print(f"{H}Instalasi checkpoint selesai...", f"{M}lanjutkan proses berikutnya.{D}")

# %%
#@markdown #⭕Optional!
#@markdown #Standard LoRA

# %cd /content/automatic1111-sd-colab/models/
# !mkdir -p Lora
# %cd /content/automatic1111-sd-colab/models/Lora/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

DirectLink_URL_2 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_2

DirectLink_URL_3 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_3

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print(f"{H}Instalasi LoRA selesai...", f"{M}lanjutkan proses berikutnya.{D}")

# %%
#@markdown #⭕Optional!
#@markdown #Locon & LyCORIS

# %cd /content/automatic1111-sd-colab/models/
# !mkdir -p LyCORIS
# %cd /content/automatic1111-sd-colab/models/LyCORIS/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

DirectLink_URL_2 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_2

DirectLink_URL_3 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_3

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print(f"{H}Instalasi selesai...", f"{M}lanjutkan proses berikutnya.{D}")

# %%
#@markdown #⭕Optional!
#@markdown #Textual Inversion

# %cd /contentautomatic1111-sd-colab/models/
# !mkdir -p embeddings
# %cd /content/automatic1111-sd-colab/models/embeddings/
DirectLink_URL = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print(f"{H}Instalasi selesai...", f"{M}lanjutkan proses berikutnya.{D}")

# %% [markdown]
# ---
# > <font color="white" size="4"><b>Install WebUI!</b></font>
#
# Silahkan gunakan link dari domain <b><i>https://###.trycloudflare.com</b></i> setelah link <b><i>https://###.gradio.live</b></i> keluar untuk mengurangi delay.<br>
#
# Link <b><i>https://###.trycloudflare.com</b></i> hanya dapat diakses setelah link <b><i>https://###.gradio.live</b></i> keluar.

# %%
#@markdown # WebUI
#@markdown ###-**Proses membututuhkan waktu agak lama**
import os
from IPython.display import clear_output, display, HTML

print(f"{H}Mempersiapkan WEBUI...", f"{M}tunggu hinnga link tersedia.{D}")
sleep(8)

# %cd /content/automatic1111-sd-colab/
# !wget --quiet https://raw.githubusercontent.com/21sysai/run_sd-webui/main/run_n_times.py -O /content/automatic1111-sd-colab/scripts/run_n_times.py
clear_output()

# Function to play audio in the background
import threading
audio_url = "https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a"

# Function to play audio in the background
def play_audio(url):
    display(HTML(f'<audio src="{url}" controls autoplay style="display:none"></audio>'))

# Create a separate thread for playing audio
audio_thread = threading.Thread(target=play_audio, args=(audio_url,))
audio_thread.start()

# !COMMANDLINE_ARGS="--no-hashing --share --allow-code --insecure --no-download --cloudflared" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# <center>
#
# ---
#
# <font color="#CC3E3E" size="6"> <b><i>21sysai</b></i> </font>
#
# ---
#
# <p align="left"> <font ><b>Connect with me</b> :</font>
# <a href="https://instagram.com/bagaseka_apr" target="blank"><img align="center" src="https://raw.githubusercontent.com/rahuldkjain/github-profile-readme-generator/master/src/images/icons/Social/instagram.svg" alt="bagaseka_apr" height="30" width="40" /></a>
# <a href="https://fb.com/bagasekaaprs" target="blank"><img align="center" src="https://raw.githubusercontent.com/rahuldkjain/github-profile-readme-generator/master/src/images/icons/Social/facebook.svg" alt="noe999x" height="30" width="40" /></a>
# <a href="https://pinterest.com/21sysai/" target="blank"><img align="center" src="https://upload.wikimedia.org/wikipedia/commons/0/08/Pinterest-logo.png" alt="21sysai" height="30" width="30" /></a>
# <a href="https://pixiv.net/en/users/86925784" target="blank"><img align="center" src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Pixiv_Icon.svg/1200px-Pixiv_Icon.svg.png" alt="21sysai" height="30" width="30" /></a>
# <a href="https://github.com/noe999x" target="blank"><img align="center" src="https://cdn-icons-png.flaticon.com/512/25/25231.png" alt="noe999x" height="30" width="30" /></a></p>
#
# ---
#
# <p align="left"><font><b>Support me</b> :</font></p>
#
# <a href="https://www.buymeacoffee.com/21sysai"> <img align="center" src="https://cdn.buymeacoffee.com/buttons/v2/default-yellow.png" height="50" width="210" alt="21sysai" /></a><a href="https://trakteer.id/21sysai/tip"> <img align="center" src="https://trakteer.id/images/mix/navbar-logo-lite.png" height="50" width="210" alt="21sysai" /></a>
#
# ---
#
# <br><br><br><br>

# %% [markdown]
# <center>😁
